# %%
import pandas as pd
adidas=pd.read_excel("Adidas_US_Sales_Datasets_1_.xlsx")

# %%
adidas
# Out:
#       Unnamed: 0     Retailer  Retailer ID Invoice Date     Region  \
# 0            NaN  Foot Locker      1185732   2020-01-01  Northeast
# 1            NaN  Foot Locker      1185732   2020-01-02  Northeast
# 2            NaN  Foot Locker      1185732   2020-01-03  Northeast
# 3            NaN  Foot Locker      1185732   2020-01-04  Northeast
# 4            NaN  Foot Locker      1185732   2020-01-05  Northeast
# ...          ...          ...          ...          ...        ...
# 9643         NaN  Foot Locker      1185732   2021-01-24  Northeast
# 9644         NaN  Foot Locker      1185732   2021-01-24  Northeast
# 9645         NaN  Foot Locker      1185732   2021-02-22  Northeast
# 9646         NaN  Foot Locker      1185732   2021-02-22  Northeast
# 9647         NaN  Foot Locker      1185732   2021-02-22  Northeast
#
#               State        City                    Product  Price per Unit  \
# 0          New York    New York      Men's Street Footwear            50.0
# ...

# %%
adidas.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9648 entries, 0 to 9647
# Data columns (total 14 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Unnamed: 0        0 non-null      float64
#  1   Retailer          9648 non-null   object
#  2   Retailer ID       9648 non-null   int64
#  3   Invoice Date      9648 non-null   datetime64[ns]
#  4   Region            9648 non-null   object
#  5   State             9648 non-null   object
#  6   City              9648 non-null   object
#  7   Product           9648 non-null   object
#  8   Price per Unit    9648 non-null   float64
#  9   Units Sold        9648 non-null   int64
#  10  Total Sales       9648 non-null   float64
#  11  Operating Profit  9648 non-null   float64
#  12  Operating Margin  9648 non-null   float64
#  13  Sales Method      9648 non-null   object
# dtypes: datetime64[ns](1), float64(5), int64(2), object(6)
# memory usage: 1.0+ MB

# %%
adidas
# Out:
#       Unnamed: 0     Retailer  Retailer ID Invoice Date     Region  \
# 0            NaN  Foot Locker      1185732   2020-01-01  Northeast
# 1            NaN  Foot Locker      1185732   2020-01-02  Northeast
# 2            NaN  Foot Locker      1185732   2020-01-03  Northeast
# 3            NaN  Foot Locker      1185732   2020-01-04  Northeast
# 4            NaN  Foot Locker      1185732   2020-01-05  Northeast
# ...          ...          ...          ...          ...        ...
# 9643         NaN  Foot Locker      1185732   2021-01-24  Northeast
# 9644         NaN  Foot Locker      1185732   2021-01-24  Northeast
# 9645         NaN  Foot Locker      1185732   2021-02-22  Northeast
# 9646         NaN  Foot Locker      1185732   2021-02-22  Northeast
# 9647         NaN  Foot Locker      1185732   2021-02-22  Northeast
#
#               State        City                    Product  Price per Unit  \
# 0          New York    New York      Men's Street Footwear            50.0
# ...

# %%
adidas['Retailer'].unique()
# Out:
# array(['Foot Locker', 'Walmart', 'Sports Direct', 'West Gear', "Kohl's",
#        'Amazon'], dtype=object)

# %%
adidas['Retailer ID'].unique()
# Out:
# array([1185732, 1197831, 1128299, 1189833], dtype=int64)

# %%
#1
list(adidas.groupby(['Retailer','Retailer ID']).groups.keys())
# Out:
# [('Amazon', 1185732),
#  ('Foot Locker', 1128299),
#  ('Foot Locker', 1185732),
#  ('Foot Locker', 1197831),
#  ("Kohl's", 1128299),
#  ("Kohl's", 1185732),
#  ("Kohl's", 1189833),
#  ("Kohl's", 1197831),
#  ('Sports Direct', 1128299),
#  ('Sports Direct', 1185732),
#  ('Sports Direct', 1197831),
#  ('Walmart', 1128299),
#  ('Walmart', 1185732),
#  ('Walmart', 1197831),
#  ('West Gear', 1128299),
#  ('West Gear', 1185732),
#  ('West Gear', 1197831)]

# %%
adidas['Region'].unique()
# Out:
# array(['Northeast', 'South', 'West', 'Midwest', 'Southeast'], dtype=object)

# %%
#2
list(adidas.groupby(['Retailer','Region']).groups.keys())
# Out:
# [('Amazon', 'Midwest'),
#  ('Amazon', 'Northeast'),
#  ('Amazon', 'South'),
#  ('Amazon', 'Southeast'),
#  ('Amazon', 'West'),
#  ('Foot Locker', 'Midwest'),
#  ('Foot Locker', 'Northeast'),
#  ('Foot Locker', 'South'),
#  ('Foot Locker', 'Southeast'),
#  ('Foot Locker', 'West'),
#  ("Kohl's", 'Midwest'),
#  ("Kohl's", 'Northeast'),
#  ("Kohl's", 'South'),
#  ("Kohl's", 'West'),
#  ('Sports Direct', 'Midwest'),
#  ('Sports Direct', 'Northeast'),
#  ('Sports Direct', 'South'),
#  ('Sports Direct', 'Southeast'),
#  ('Sports Direct', 'West'),
#  ('Walmart', 'Northeast'),
#  ('Walmart', 'South'),
#  ('Walmart', 'Southeast'),
#  ('Walmart', 'West'),
#  ('West Gear', 'Midwest'),
#  ('West Gear', 'Northeast'),
#  ('West Gear', 'South'),
#  ('West Gear', 'Southeast'),
#  ('West Gear', 'West')]

# %%
#3
list(adidas.groupby(['State','City','Retailer']).groups.keys())
# Out:
# [('Alabama', 'Birmingham', 'Amazon'),
#  ('Alabama', 'Birmingham', 'Sports Direct'),
#  ('Alaska', 'Anchorage', 'Amazon'),
#  ('Alaska', 'Anchorage', 'Foot Locker'),
#  ('Arizona', 'Phoenix', 'Foot Locker'),
#  ('Arizona', 'Phoenix', "Kohl's"),
#  ('Arkansas', 'Little Rock', 'Walmart'),
#  ('Arkansas', 'Little Rock', 'West Gear'),
#  ('California', 'Los Angeles', 'Foot Locker'),
#  ('California', 'Los Angeles', "Kohl's"),
#  ('California', 'San Francisco', "Kohl's"),
#  ('California', 'San Francisco', 'West Gear'),
#  ('Colorado', 'Denver', 'West Gear'),
#  ('Connecticut', 'Hartford', 'Foot Locker'),
#  ('Connecticut', 'Hartford', 'Sports Direct'),
#  ('Delaware', 'Wilmington', 'Foot Locker'),
#  ('Delaware', 'Wilmington', "Kohl's"),
#  ('Florida', 'Miami', 'Foot Locker'),
#  ('Florida', 'Miami', 'Sports Direct'),
#  ('Florida', 'Miami', 'West Gear'),
#  ('Florida', 'Orlando', 'Sports Direct'),
#  ('Florida', 'Orlando', 'Walmart'),
#  ('Florida', 'Orlando', 'West Gear'),
# ...

# %%
#4
list(adidas.groupby(['Retailer','City','Units Sold']).groups.keys())
# Out:
# [('Amazon', 'Anchorage', 36),
#  ('Amazon', 'Anchorage', 41),
#  ('Amazon', 'Anchorage', 42),
#  ('Amazon', 'Anchorage', 44),
#  ('Amazon', 'Anchorage', 46),
#  ('Amazon', 'Anchorage', 53),
#  ('Amazon', 'Anchorage', 56),
#  ('Amazon', 'Anchorage', 59),
#  ('Amazon', 'Anchorage', 60),
#  ('Amazon', 'Anchorage', 61),
#  ('Amazon', 'Anchorage', 63),
#  ('Amazon', 'Anchorage', 65),
#  ('Amazon', 'Anchorage', 68),
#  ('Amazon', 'Anchorage', 69),
#  ('Amazon', 'Anchorage', 72),
#  ('Amazon', 'Anchorage', 75),
#  ('Amazon', 'Anchorage', 77),
#  ('Amazon', 'Anchorage', 81),
#  ('Amazon', 'Anchorage', 83),
#  ('Amazon', 'Anchorage', 84),
#  ('Amazon', 'Anchorage', 90),
#  ('Amazon', 'Anchorage', 91),
#  ('Amazon', 'Anchorage', 93),
#  ('Amazon', 'Anchorage', 100),
#  ('Amazon', 'Anchorage', 101),
#  ('Amazon', 'Anchorage', 102),
#  ('Amazon', 'Anchorage', 104),
#  ('Amazon', 'Anchorage', 106),
#  ('Amazon', 'Anchorage', 111),
#  ('Amazon', 'Anchorage', 112),
#  ('Amazon', 'Anchorage', 113),
# ...

# %%
#5
adidas.groupby('Retailer')['Total Sales'].sum()
# Out:
# Retailer
# Amazon            77698912.0
# Foot Locker      220094720.0
# Kohl's           102114753.0
# Sports Direct    182470997.0
# Walmart           74558410.0
# West Gear        242964333.0
# Name: Total Sales, dtype: float64

# %%
#6
adidas.groupby(['Retailer',
            'City'])[['Total Sales','Operating Profit']].sum()
# Out:
#                           Total Sales  Operating Profit
# Retailer  City
# Amazon    Anchorage        13365025.0        4143804.75
#           Birmingham         409091.0         146947.48
#           Boston            4193590.0        1375377.31
#           Burlington       13380463.0        5376161.02
#           Charlotte         3733676.0        1532481.72
# ...                               ...               ...
# West Gear Portland         21934257.0        7712540.80
#           Salt Lake City    9696420.0        3873429.10
#           San Francisco    33360397.0        9843005.12
#           Seattle          24862675.0        6469771.84
#           St. Louis         1701133.0         681457.25
#
# [108 rows x 2 columns]

# %%
#7
adidas.groupby(['Retailer',
            'Product'])[['Total Sales','Operating Profit']].sum()
# Out:
#                                          Total Sales  Operating Profit
# Retailer      Product
# Amazon        Men's Apparel               10474770.0        3331443.80
#               Men's Athletic Footwear     12011959.0        4518030.11
#               Men's Street Footwear       22161652.0        8707658.12
#               Women's Apparel             15710639.0        6280071.53
#               Women's Athletic Footwear    7935255.0        2701607.74
#               Women's Street Footwear      9404637.0        3279692.01
# Foot Locker   Men's Apparel               29508995.0        9942404.61
#               Men's Athletic Footwear     36480415.0       12409221.49
#               Men's Street Footwear       57481575.0       23060809.17
#               Women's Apparel             43296114.0       17192901.49
#               Women's Athletic Footwear   24239624.0        8477313.73
#               Women's Street Footwear     29087997.0        9639474.32
# ...

# %%
#8
adidas[(adidas['Invoice Date']>'1/1/2020') & 
    (adidas['Invoice Date']<'4/15/2020')].groupby('Product')[['Units Sold','Total Sales','Operating Profit']].sum()
# Out:
#                            Units Sold  Total Sales  Operating Profit
# Product
# Men's Apparel                   17060    7030470.0        2876971.09
# Men's Athletic Footwear         25036    9339031.0        2522862.64
# Men's Street Footwear           29452   10886829.0        4897565.46
# Women's Apparel                 22513    9388987.0        2096407.03
# Women's Athletic Footwear       19980    6889592.0        2398964.20
# Women's Street Footwear         23442    8014382.0        3022311.95

# %%
len(adidas['Product'].unique())
# Out:
# 6

# %%
#9
adidas.groupby(['Retailer','Product','City'])['Units Sold'].sum()
# Out:
# Retailer   Product                  City
# Amazon     Men's Apparel            Anchorage          2990
#                                     Boston             1235
#                                     Burlington         4607
#                                     Charlotte          1447
#                                     Columbus           6054
#                                                       ...
# West Gear  Women's Street Footwear  Portland           9168
#                                     Salt Lake City     7303
#                                     San Francisco     13346
#                                     Seattle            6888
#                                     St. Louis          1678
# Name: Units Sold, Length: 618, dtype: int64

# %%
#10
adidas.drop_duplicates(['Product','City','Price per Unit']).groupby('Product').groups.keys()
# Out:
# dict_keys(["Men's Apparel", "Men's Athletic Footwear", "Men's Street Footwear", "Women's Apparel", "Women's Athletic Footwear", "Women's Street Footwear"])

# %%
adidas['Product'].nunique()
# Out:
# 6

# %%
#11
adidas.groupby(adidas['Invoice Date'].dt.strftime('%B'))[['Total Sales', 'Operating Profit']].sum()
# Out:
#               Total Sales  Operating Profit
# Invoice Date
# April          72339970.0       27559237.31
# August         92166201.0       34451440.30
# December       85841957.0       31590202.03
# February       61100153.0       21392736.70
# January        71479142.0       25141934.51
# July           95480694.0       34054898.59
# June           74747372.0       26714715.92
# March          56809109.0       20439788.00
# May            80507695.0       29946255.33
# November       67857340.0       24755521.43
# October        63911033.0       25078444.60
# September      77661459.0       31009586.73

# %%
#12
adidas.groupby(['Product','City','Sales Method'])[['Total Sales','Operating Profit']].sum()
# Out:
#                                                   Total Sales  \
# Product                 City        Sales Method
# Men's Apparel           Albany      In-store        3776250.0
#                                     Online            97303.0
#                         Albuquerque Online          2472312.0
#                                     Outlet            56032.0
#                         Anchorage   Online            43774.0
# ...                                                       ...
# Women's Street Footwear St. Louis   In-store        1050000.0
#                                     Online            28374.0
#                         Wichita     Online          1116162.0
#                         Wilmington  In-store        1464750.0
#                                     Online            37547.0
#
#                                                   Operating Profit
# Product                 City        Sales Method
# ...

# %%
#13
list(adidas.groupby(['Retailer','Product','Price per Unit']).groups.keys())
# Out:
# [('Amazon', "Men's Apparel", 32.0),
#  ('Amazon', "Men's Apparel", 35.0),
#  ('Amazon', "Men's Apparel", 36.0),
#  ('Amazon', "Men's Apparel", 37.0),
#  ('Amazon', "Men's Apparel", 39.0),
#  ('Amazon', "Men's Apparel", 40.0),
#  ('Amazon', "Men's Apparel", 40.00000000000001),
#  ('Amazon', "Men's Apparel", 41.0),
#  ('Amazon', "Men's Apparel", 42.0),
#  ('Amazon', "Men's Apparel", 43.0),
#  ('Amazon', "Men's Apparel", 44.0),
#  ('Amazon', "Men's Apparel", 45.0),
#  ('Amazon', "Men's Apparel", 46.0),
#  ('Amazon', "Men's Apparel", 47.0),
#  ('Amazon', "Men's Apparel", 48.0),
#  ('Amazon', "Men's Apparel", 49.0),
#  ('Amazon', "Men's Apparel", 49.99999999999999),
#  ('Amazon', "Men's Apparel", 50.0),
#  ('Amazon', "Men's Apparel", 51.0),
#  ('Amazon', "Men's Apparel", 52.0),
#  ('Amazon', "Men's Apparel", 53.0),
#  ('Amazon', "Men's Apparel", 54.0),
#  ('Amazon', "Men's Apparel", 54.99999999999999),
#  ('Amazon', "Men's Apparel", 55.0),
# ...
